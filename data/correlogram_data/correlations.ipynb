# %%
import pandas as pd
import numpy as np
import csv
from scipy.stats import pearsonr

# %%
df_2015 = pd.read_csv("../cleaned_data/2015.csv")
df_2016 = pd.read_csv("../cleaned_data/2016.csv")
df_2017 = pd.read_csv("../cleaned_data/2017.csv")
df_2018 = pd.read_csv("../cleaned_data/2018.csv")
df_2019 = pd.read_csv("../cleaned_data/2019.csv")
df_2019.head()
# Out:
#        Country                           Region  Happiness_Rank  \
# 0  Afghanistan                    Southern Asia             154
# 1      Albania       Central and Eastern Europe             107
# 2      Algeria  Middle East and Northern Africa              88
# 3    Argentina      Latin America and Caribbean              47
# 4      Armenia       Central and Eastern Europe             116
#
#    Happiness_Score  Economy  Family  Health  Freedom  Trust  Generosity  \
# 0            3.203    0.350   0.517   0.361    0.000  0.025       0.158
# 1            4.719    0.947   0.848   0.874    0.383  0.027       0.178
# 2            5.211    1.002   1.160   0.785    0.086  0.114       0.073
# 3            6.086    1.092   1.432   0.881    0.471  0.050       0.066
# 4            4.559    0.850   1.055   0.815    0.283  0.064       0.095
#
#    Dystopia_Residual
# 0              1.792
# 1              1.462
# 2              1.991
# 3              2.094
# 4              1.397

# %%
# Summary Statistics for 2019
df_2019.loc[:,"Happiness_Score"].describe()
# Out:
# count    156.000000
# mean       5.407096
# std        1.113120
# min        2.853000
# 25%        4.544500
# 50%        5.379500
# 75%        6.184500
# max        7.769000
# Name: Happiness_Score, dtype: float64

# %%
# Group by Region
regions_2019 = df_2019.groupby("Region").mean()
regions_2019
# Out:
#                                  Happiness_Rank  Happiness_Score   Economy  \
# Region
# Australia and New Zealand              9.500000         7.267500  1.337500
# Central and Eastern Europe            70.965517         5.561517  1.021069
# Eastern Asia                          64.833333         5.688833  1.235167
# Latin America and Caribbean           51.380952         5.954429  0.924286
# Middle East and Northern Africa       84.894737         5.237000  1.059053
# North America                         14.000000         7.085000  1.399000
# Southeastern Asia                     85.111111         5.273667  0.930000
# Southern Asia                        115.857143         4.526857  0.650286
# Sub-Saharan Africa                   124.800000         4.300050  0.443750
# Western Europe                        23.380952         6.842190  1.357333
#
#                                    Family    Health   Freedom     Trust  \
# Region
# Australia and New Zealand        1.552500  1.031000  0.571000  0.335000
# Central and Eastern Europe       1.338793  0.809517  0.357517  0.061759
# Eastern Asia                     1.333500  0.953333  0.372167  0.119667
# Latin America and Caribbean      1.339714  0.811857  0.440905  0.072048
# Middle East and Northern Africa  1.148684  0.751053  0.317947  0.105000
# North America                    1.481000  0.956500  0.519000  0.218000
# Southeastern Asia                1.246444  0.745333  0.543778  0.123444
# Southern Asia                    0.986857  0.617000  0.386286  0.093429
# Sub-Saharan Africa               0.916675  0.407550  0.337350  0.094500
# Western Europe                   1.472857  1.015190  0.479429  0.218381
#
#                                  Generosity  Dystopia_Residual
# Region
# Australia and New Zealand          0.331000           2.109500
# Central and Eastern Europe         0.142724           1.830138
# Eastern Asia                       0.172833           1.502167
# Latin America and Caribbean        0.144619           2.221000
# Middle East and Northern Africa    0.153474           1.701789
# North America                      0.282500           2.229000
# Southeastern Asia                  0.301778           1.382889
# Southern Asia                      0.234714           1.558286
# Sub-Saharan Africa                 0.187725           1.912500
# Western Europe                     0.219619           2.079381

# %%
# Summary statistics for 2019 Health
regions_2019["Health"].describe()
# Out:
# count    10.000000
# mean      0.809833
# std       0.194315
# min       0.407550
# 25%       0.746763
# 50%       0.810687
# 75%       0.955708
# max       1.031000
# Name: Health, dtype: float64

# %%
# Slice the df
df2_2019 = df_2019.iloc[:,3:11]
df2_2019.head()
# Out:
#    Happiness_Score  Economy  Family  Health  Freedom  Trust  Generosity  \
# 0            3.203    0.350   0.517   0.361    0.000  0.025       0.158
# 1            4.719    0.947   0.848   0.874    0.383  0.027       0.178
# 2            5.211    1.002   1.160   0.785    0.086  0.114       0.073
# 3            6.086    1.092   1.432   0.881    0.471  0.050       0.066
# 4            4.559    0.850   1.055   0.815    0.283  0.064       0.095
#
#    Dystopia_Residual
# 0              1.792
# 1              1.462
# 2              1.991
# 3              2.094
# 4              1.397

# %%
years = [2015, 2016, 2017, 2018, 2019]

# For each year
for k in range(len(years)):    
    
    # Read input file
    old_df = pd.read_csv(f"../cleaned_data/{years[k]}.csv")

    # Slice the df
    new_df = old_df.iloc[:,3:11]
    
    # Create a correlations table
    corr_table = []

    # Add factor titles in first row
    headers = new_df.columns
    headers = headers.insert(0,"")
    corr_table.append(headers)
    
    # First factor index
    for i in range(len(new_df.columns)):

        corr_row = []
        
        # Add factor titles in first column
        corr_row.append(new_df.columns[i])

        # Second factor index
        for j in range(len(new_df.columns)):
            
            # First factor column
            col1 = new_df.iloc[:,i]
            # Second factor column
            col2 = new_df.iloc[:,j]
            # Calculate correlation coefficient
            corr, _ = pearsonr(col2, col1)
            
            # Add table cell to row
            corr_row.append(corr)

        # Add row to table
        corr_table.append(corr_row)

    # Convert to dataframe    
    corr_df = pd.DataFrame(corr_table)

    # Export to CSV
    corr_df.to_csv(f'correlations_{years[k]}.csv', index=False, header=False)
